# %% [markdown]
# **Deploy Finetuned transformers (BERT) model**
#
# Push model to huggingface hub
# Deploy it on streamlit cloud
#
# **Why Push model on Huggingface Hub**
#
# Huggingface hub is like github for ML models
# Deployment Docker file will be smaller
# Updated or Re-trained model will be availabe without redeployement.

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 12.6 MB/s eta 0:00:00
# ...

# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained("/content/drive/MyDrive/NLP/FineTuneBertModel_TextClassification/CustomModel")

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model.push_to_hub("ankitmarwaha/FineTuneBertModel")
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/ankitmarwaha/FineTuneBertModel/commit/d02aae597e470d6edcd5e4c8e1f73fe29a94b3b9', commit_message='Upload BertForSequenceClassification', commit_description='', oid='d02aae597e470d6edcd5e4c8e1f73fe29a94b3b9', pr_url=None, pr_revision=None, pr_num=None)

# %%
model = BertForSequenceClassification.from_pretrained("ankitmarwaha/FineTuneBertModel")
